# %% [markdown]
# Me he registrado en OpenAI y he creado una API. En la documentación oficial pone que se pueden hacer llamadas gratuitas via API.
#
# https://platform.openai.com/docs/guides/rate-limits
#
# ![image.png](data:image/png;base64,...)

# %%
from openai import OpenAI
import os
from dotenv import load_dotenv
load_dotenv()
client = OpenAI(
  api_key=os.getenv("LLMsAPIkey_OpenAI")
)

completion = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {"role": "developer", "content": "You are a helpful assistant."},
        {
            "role": "user",
            "content": "Tell me a joke about Physics"
        }
    ]
)

print(completion.choices[0].message)
# Out:
# ChatCompletionMessage(content="Why can't you trust an atom?\n\nBecause they make up everything!", refusal=None, role='assistant', audio=None, function_call=None, tool_calls=None)
